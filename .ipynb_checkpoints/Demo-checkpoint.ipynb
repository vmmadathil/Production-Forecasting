# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
production = pd.read_csv("time_series_60min_singleindex_filtered.csv",
                        parse_dates=[0], index_col=0)

# %%
production.head()
# Out:
#                            cet_cest_timestamp interpolated_values  \
# utc_timestamp
# 2005-12-31 23:00:00  2006-01-01T00:00:00+0100                 NaN
# 2006-01-01 00:00:00  2006-01-01T01:00:00+0100                 NaN
# 2006-01-01 01:00:00  2006-01-01T02:00:00+0100                 NaN
# 2006-01-01 02:00:00  2006-01-01T03:00:00+0100                 NaN
# 2006-01-01 03:00:00  2006-01-01T04:00:00+0100                 NaN
#
#                      FR_load_entsoe_power_statistics  \
# utc_timestamp
# 2005-12-31 23:00:00                          63245.0
# 2006-01-01 00:00:00                          63616.0
# 2006-01-01 01:00:00                          61480.0
# 2006-01-01 02:00:00                          58000.0
# 2006-01-01 03:00:00                          55635.0
#
#                      FR_load_entsoe_transparency  FR_price_day_ahead  \
# utc_timestamp
# 2005-12-31 23:00:00                          NaN                 NaN
# 2006-01-01 00:00:00                          NaN                 NaN
# 2006-01-01 01:00:00                          NaN                 NaN
# 2006-01-01 02:00:00                          NaN                 NaN
# 2006-01-01 03:00:00                          NaN                 NaN
#
#                      FR_solar_generation_actual  \
# utc_timestamp
# 2005-12-31 23:00:00                         NaN
# 2006-01-01 00:00:00                         NaN
# 2006-01-01 01:00:00                         NaN
# 2006-01-01 02:00:00                         NaN
# 2006-01-01 03:00:00                         NaN
#
#                      FR_wind_onshore_generation_actual
# utc_timestamp
# 2005-12-31 23:00:00                                NaN
# 2006-01-01 00:00:00                                NaN
# 2006-01-01 01:00:00                                NaN
# 2006-01-01 02:00:00                                NaN
# 2006-01-01 03:00:00                                NaN
